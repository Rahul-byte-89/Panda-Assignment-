# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_excel("Pandas assignment netflix file.xlsx")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8775   s8803    Movie                 Zodiac    David Fincher
# 8776   s8804  TV Show            Zombie Dumb              NaN
# 8777   s8805    Movie             Zombieland  Ruben Fleischer
# 8778   s8806    Movie                   Zoom     Peter Hewitt
# 8779   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#First five rows
data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#last 5 rows
data.tail(5)
# Out:
#      show_id     type        title         director  \
# 8775   s8803    Movie       Zodiac    David Fincher
# 8776   s8804  TV Show  Zombie Dumb              NaN
# 8777   s8805    Movie   Zombieland  Ruben Fleischer
# 8778   s8806    Movie         Zoom     Peter Hewitt
# 8779   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8775  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8776                                                NaN            NaN
# 8777  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8778  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8779  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8775  November 20, 2019          2007      R    158 min
# 8776       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8775   s8803    Movie                 Zodiac    David Fincher
# 8776   s8804  TV Show            Zombie Dumb              NaN
# 8777   s8805    Movie             Zombieland  Ruben Fleischer
# 8778   s8806    Movie                   Zoom     Peter Hewitt
# 8779   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#B.
data.count
# Out:
# <bound method DataFrame.count of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8775   s8803    Movie                 Zodiac    David Fincher
# 8776   s8804  TV Show            Zombie Dumb              NaN
# 8777   s8805    Movie             Zombieland  Ruben Fleischer
# 8778   s8806    Movie                   Zoom     Peter Hewitt
# 8779   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
#C 
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
#D.
data.describe()
# Out:
#        release_year
# count   8780.000000
# mean    2014.178474
# std        8.827938
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
#E.
data.nunique()
# Out:
# show_id         8780
# type               2
# title           8780
# director        4516
# cast            7671
# country          745
# date_added      1765
# release_year      74
# rating            14
# duration         220
# listed_in        514
# dtype: int64

# %%
#F.
data.isnull().mean()*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.954442
# cast             9.384966
# country          9.430524
# date_added       0.113895
# release_year     0.000000
# rating           0.045558
# duration         0.000000
# listed_in        0.000000
# dtype: float64

# %%
#G.
data.dropna(subset=['director'],inplace=True)

# %%
print(data)
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8774   s8802    Movie                           Zinzana
# 8775   s8803    Movie                            Zodiac
# 8777   s8805    Movie                        Zombieland
# 8778   s8806    Movie                              Zoom
# 8779   s8807    Movie                            Zubaan
#
#                             director  \
# 0                    Kirsten Johnson
# 2                    Julien Leclercq
# 5                      Mike Flanagan
# 6     Robert Cullen, JosÃ© Luis Ucha
# 7                       Haile Gerima
# ...                              ...
# ...

# %%
# Number of rows has come down [6150 rows x 11 columns]

# %%
#H
Germany=data[data['country'].isin(['Germany', 'West Germany'])]

# %%
print(Germany)
# Out:
#      show_id   type                                       title  \
# 705     s706  Movie                              Biking Borders
# 1030   s1032  Movie                               Into the Beat
# 1196   s1199  Movie        RebellComedy: Straight Outta the Zoo
# 1250   s1253  Movie                        How to Be Really Bad
# 1265   s1268  Movie                                    Who Am I
# 1590   s1593  Movie                         Christmas Crossfire
# 1740   s1743  Movie                        Felix Lobrecht: Hype
# 2053   s2056  Movie                 Freaks â€“ You're One of Us
# 2147   s2151  Movie            Berlin, Berlin: Lolle on the Run
# 2182   s2186  Movie              Latte and the Magic Waterstone
# 2667   s2672  Movie                                 Rising High
# 2772   s2777  Movie                           Making Unorthodox
# 2890   s2896  Movie                              System Crasher
# 2909   s2915  Movie                                  Isi & Ossi
# ...

# %%
# I
data[['Duration_num', 'Duration_str']] = data['duration'].str.extract(r'(\d+)\s*(\D+)')
data['Duration_num'] = data['Duration_num'].astype(int)
data.head()
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
#
#                          director  \
# 0                 Kirsten Johnson
# 2                 Julien Leclercq
# 5                   Mike Flanagan
# 6  Robert Cullen, JosÃ© Luis Ucha
# 7                    Haile Gerima
#
#                                                 cast  \
# 0                                                NaN
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country          date_added  \
# ...

# %%
# J
data = data.drop(columns=['Month', 'Day', 'Year'], errors='ignore')

data['date_added'] = data['date_added'].str.replace(',', '')

split_cols = data['date_added'].str.split(' ', n=2, expand=True)
split_cols.columns = ['Month', 'Day', 'Year']

data = data.join(split_cols)

data['Day'] = pd.to_numeric(data['Day'], errors='coerce')
data['Year'] = pd.to_numeric(data['Year'], errors='coerce')

data.head()
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
#
#                          director  \
# 0                 Kirsten Johnson
# 2                 Julien Leclercq
# 5                   Mike Flanagan
# 6  Robert Cullen, JosÃ© Luis Ucha
# 7                    Haile Gerima
#
#                                                 cast  \
# 0                                                NaN
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country         date_added  \
# ...

# %%
# K
year_counts = data['release_year'].value_counts().sort_index()
print(year_counts)
# Out:
# release_year
# 1942      2
# 1943      3
# 1944      3
# 1945      3
# 1946      2
#        ...
# 2017    771
# 2018    757
# 2019    623
# 2020    548
# 2021    297
# Name: count, Length: 73, dtype: int64

# %%
# L
data=data.rename(columns={'title':'movie_title'})

# %%
print(data)
# Out:
#      show_id     type                       movie_title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8774   s8802    Movie                           Zinzana
# 8775   s8803    Movie                            Zodiac
# 8777   s8805    Movie                        Zombieland
# 8778   s8806    Movie                              Zoom
# 8779   s8807    Movie                            Zubaan
#
#                             director  \
# 0                    Kirsten Johnson
# 2                    Julien Leclercq
# 5                      Mike Flanagan
# 6     Robert Cullen, JosÃ© Luis Ucha
# 7                       Haile Gerima
# ...                              ...
# ...

# %%
#M
data[['Genre1', 'Genre2', 'Genre3']] = data['listed_in'].str.split(',', n=2, expand=True)

# %%
data
# Out:
#      show_id     type                       movie_title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8774   s8802    Movie                           Zinzana
# 8775   s8803    Movie                            Zodiac
# 8777   s8805    Movie                        Zombieland
# 8778   s8806    Movie                              Zoom
# 8779   s8807    Movie                            Zubaan
#
#                             director  \
# 0                    Kirsten Johnson
# 2                    Julien Leclercq
# 5                      Mike Flanagan
# 6     Robert Cullen, JosÃ© Luis Ucha
# 7                       Haile Gerima
# ...                              ...
# ...

# %%
A=pd.read_excel('student.xlsx')

# %%
A
# Out:
#      Student_id  Age  Gender      Grade Employed
# 0             1   19    Male  1st Class      yes
# 1             2   20  Female  2nd Class       no
# 2             3   18    Male  1st Class       no
# 3             4   21  Female  2nd Class       no
# 4             5   19    Male  1st Class       no
# ..          ...  ...     ...        ...      ...
# 227         228   21  Female  1st Class       no
# 228         229   20    Male  2nd Class       no
# 229         230   20    Male  3rd Class      yes
# 230         231   19  Female  1st Class      yes
# 231         232   20    Male  3rd Class      yes
#
# [232 rows x 5 columns]

# %%
B=pd.read_csv('marks.csv')

# %%
B
# Out:
#      Student_id  Mark     City
# 0             1    95  Chennai
# 1             2    70    Delhi
# 2             3    98   Mumbai
# 3             4    75     Pune
# 4             5    89    Kochi
# ..          ...   ...      ...
# 224         228    99     Pune
# 225         229    70  Chennai
# 226         230    55    Delhi
# 227         231    97   Mumbai
# 228         232    59     Pune
#
# [229 rows x 3 columns]

# %%
#A
df=pd.concat([A,B],ignore_index=True)

# %%
df
# Out:
#      Student_id   Age  Gender      Grade Employed  Mark     City
# 0             1  19.0    Male  1st Class      yes   NaN      NaN
# 1             2  20.0  Female  2nd Class       no   NaN      NaN
# 2             3  18.0    Male  1st Class       no   NaN      NaN
# 3             4  21.0  Female  2nd Class       no   NaN      NaN
# 4             5  19.0    Male  1st Class       no   NaN      NaN
# ..          ...   ...     ...        ...      ...   ...      ...
# 456         228   NaN     NaN        NaN      NaN  99.0     Pune
# 457         229   NaN     NaN        NaN      NaN  70.0  Chennai
# 458         230   NaN     NaN        NaN      NaN  55.0    Delhi
# 459         231   NaN     NaN        NaN      NaN  97.0   Mumbai
# 460         232   NaN     NaN        NaN      NaN  59.0     Pune
#
# [461 rows x 7 columns]

# %%
#B
result=df.groupby('Gender')['Mark'].agg(['max','min'])
print(result)
# Out:
#         max  min
# Gender
# Female  NaN  NaN
# Male    NaN  NaN

# %%
#C.
average_marks=df['Mark'].mean()

# %%
print(average_marks)
# Out:
# 71.38864628820961

# %%
above_avg_students = df[df['Mark'] > average_marks][['Student_id', 'Mark']]
print(above_avg_students)
# Out:
#      Student_id  Mark
# 232           1  95.0
# 234           3  98.0
# 235           4  75.0
# 236           5  89.0
# 241          12  90.0
# ..          ...   ...
# 450         222  74.0
# 451         223  79.0
# 453         225  72.0
# 456         228  99.0
# 459         231  97.0
#
# [137 rows x 2 columns]

# %%
#D.
filtered_df = df[(df['Gender'] == 'Male') & (df['Employed'])]
print(filtered_df)
# Out:
#      Student_id   Age Gender      Grade Employed  Mark City
# 0             1  19.0   Male  1st Class      yes   NaN  NaN
# 2             3  18.0   Male  1st Class       no   NaN  NaN
# 4             5  19.0   Male  1st Class       no   NaN  NaN
# 5             6  20.0   Male  2nd Class      yes   NaN  NaN
# 7             8  21.0   Male  3rd Class      yes   NaN  NaN
# ..          ...   ...    ...        ...      ...   ...  ...
# 224         225  19.0   Male  2nd Class       no   NaN  NaN
# 226         227  22.0   Male  3rd Class       no   NaN  NaN
# 228         229  20.0   Male  2nd Class       no   NaN  NaN
# 229         230  20.0   Male  3rd Class      yes   NaN  NaN
# 231         232  20.0   Male  3rd Class      yes   NaN  NaN
#
# [136 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Student_id', 'Age', 'Gender', 'Grade', 'Employed', 'Mark', 'City'], dtype='object')

# %%
#E.
import numpy as np

df['IQ_level'] = np.where(df['Mark'] > 80, 'Intelligent',
                    np.where(df['Mark'] >= 50, 'Mediocre', 'Weak'))

# %%
print(df)
# Out:
#      Student_id   Age  Gender      Grade Employed  Mark     City     IQ_level
# 0             1  19.0    Male  1st Class      yes   NaN      NaN         Weak
# 1             2  20.0  Female  2nd Class       no   NaN      NaN         Weak
# 2             3  18.0    Male  1st Class       no   NaN      NaN         Weak
# 3             4  21.0  Female  2nd Class       no   NaN      NaN         Weak
# 4             5  19.0    Male  1st Class       no   NaN      NaN         Weak
# ..          ...   ...     ...        ...      ...   ...      ...          ...
# 456         228   NaN     NaN        NaN      NaN  99.0     Pune  Intelligent
# 457         229   NaN     NaN        NaN      NaN  70.0  Chennai     Mediocre
# 458         230   NaN     NaN        NaN      NaN  55.0    Delhi     Mediocre
# 459         231   NaN     NaN        NaN      NaN  97.0   Mumbai  Intelligent
# 460         232   NaN     NaN        NaN      NaN  59.0     Pune     Mediocre
#
# [461 rows x 8 columns]

# %%
#F.
gender_city_counts = df.groupby(['City', 'Gender']).size().unstack(fill_value=0)

print(gender_city_counts)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#G.
top_5_Male_scorers = df[df['Gender'] == 'Male'].sort_values(by='Mark', ascending=False).head(5)

print(top_5_Male_scorers)
# Out:
#    Student_id   Age Gender      Grade Employed  Mark City IQ_level
# 0           1  19.0   Male  1st Class      yes   NaN  NaN     Weak
# 2           3  18.0   Male  1st Class       no   NaN  NaN     Weak
# 4           5  19.0   Male  1st Class       no   NaN  NaN     Weak
# 5           6  20.0   Male  2nd Class      yes   NaN  NaN     Weak
# 7           8  21.0   Male  3rd Class      yes   NaN  NaN     Weak

# %%
#H.
df2= df2['Gender'].replace({'Male': 'M', 'Female': 'F'})
print(df)
# Out:
# 0        M
# 1        F
# 2        M
# 3        F
# 4        M
#       ...
# 456    NaN
# 457    NaN
# 458    NaN
# 459    NaN
# 460    NaN
# Name: Gender, Length: 461, dtype: object

# %%
df.to_csv(r'D:\test.csv', index=False)

# %%
# I
duplicates = df['Student_id'].duplicated()
print(duplicates)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 456     True
# 457     True
# 458     True
# 459     True
# 460     True
# Name: Student_id, Length: 461, dtype: bool

# %%
#J
numeric_df = data.select_dtypes(include=['number'])

# %%
print(numeric_df)
# Out:
#       release_year  Duration_num   Day    Year
# 0             2020            90  25.0  2021.0
# 2             2021             1  24.0  2021.0
# 5             2021             1  24.0  2021.0
# 6             2021            91  24.0  2021.0
# 7             1993           125  24.0  2021.0
# ...            ...           ...   ...     ...
# 8774          2015            96   9.0  2016.0
# 8775          2007           158  20.0  2019.0
# 8777          2009            88   1.0  2019.0
# 8778          2006            88  11.0  2020.0
# 8779          2015           111   2.0  2019.0
#
# [6150 rows x 4 columns]

# %%
# K

import pandas as pd


students_df = pd.read_excel("student.xlsx", sheet_name="student")
marks_df = pd.read_excel("Test_file.xlsx", sheet_name="Sheet1")


student_ids_not_in_marks = students_df[~students_df['Student_id'].isin(marks_df['ID'])]


print(student_ids_not_in_marks[['Student_id']])
# Out:
#      Student_id
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
# ..          ...
# 227         228
# 228         229
# 229         230
# 230         231
# 231         232
#
# [227 rows x 1 columns]

# %% [raw]
# #Q.3
# 1. Concept of Missing Values
# Definition:
# A missing value occurs when data is not available for a given observation.
# 2. Identifying Missing Values in Pandas
# We can check for missing values using:
# import pandas as pd
# import numpy as np
#
# # Example DataFrame
# data = data = {
#     'Name': ['John', 'Sara', 'Mike', None],
#     'Age': [25, None, 30, 22],
#     'Score': [85, 90, None, 88]
# }
# df = pd.DataFrame(data)
#
# print(df.isnull())
#
# print(df.isnull().sum())
#
# print(df.isnull().sum().sum())
#
# 3. Ways to Handle Missing Values
# A. Deleting Missing Values
# Remove rows with any missing value
#
# df_dropped_rows = df.dropna()
#
# 2.Remove columns with any missing value
#   df_dropped_cols = df.dropna(axis=1)
#
# B. Imputing (Filling) Missing Values
# Fill with a constant
# df_fill_constant = df.fillna(0)
#
# 2.Fill with column mean/median/mode
#
# df['Age'].fillna(df['Age'].mean(), inplace=True)
# df['Score'].fillna(df['Score'].median(), inplace=True)
#
# 3.Forward Fill (fill from previous row)
#
# df_ffill = df.fillna(method='ffill')
#
# 4.Backward Fill (fill from next row)
#
# df_bfill = df.fillna(method='bfill')
